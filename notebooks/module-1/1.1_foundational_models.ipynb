# %%
import sys
print(sys.executable)
# Out:
# c:\Users\TONY\Downloads\langchain-agent\.venv\Scripts\python.exe

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-4.1")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="The Moon does not have a capital. It is not a country or a sovereign entity; rather, it is Earth's only natural satellite. No nation officially claims ownership of the Moon, as outlined by the 1967 Outer Space Treaty, which prohibits any government from claiming celestial bodies. There are no permanent human settlements or established cities on the Moon; only robotic missions and brief human visits (e.g., the Apollo landings) have occurred. \n\nSo, currently, **the Moon has no capital**.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 101, 'prompt_tokens': 14, 'total_tokens': 115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_ea6701c72a', 'id': 'chatcmpl-DSbc1PK91i7oXWkyd94K8sVwPFQfe', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d7092-69a5-7b83-8913-45d339668382-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 101, 'total_tokens': 115, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(response.content)
# Out:
# The Moon does not have a capital. It is not a country or a sovereign entity; rather, it is Earth's only natural satellite. No nation officially claims ownership of the Moon, as outlined by the 1967 Outer Space Treaty, which prohibits any government from claiming celestial bodies. There are no permanent human settlements or established cities on the Moon; only robotic missions and brief human visits (e.g., the Apollo landings) have occurred.
#
# So, currently, **the Moon has no capital**.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DSbc1PK91i7oXWkyd94K8sVwPFQfe',
#  'logprobs': None,
#  'model_name': 'gpt-4.1-2025-04-14',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_ea6701c72a',
#  'token_usage': {'completion_tokens': 101,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 0,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 14,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 115}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There is no capital on the Moon. It has no government or inhabitants. If you meant something playful: the capital letter of the word “Moon” is M.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
from langchain.agents import create_agent
agent = create_agent("gpt-4.1")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='f4f4cd75-dc07-413b-8320-9c380a914e76'),
#               AIMessage(content='The Moon does not have a capital. It is Earth’s natural satellite and does not have any permanent human settlements, governments, or cities—meaning there is no capital city or administrative center on the Moon. If you have any other lunar questions, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 14, 'total_tokens': 68, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_ea6701c72a', 'id': 'chatcmpl-DSbcgPRzKou7xfyNUR2y7xcS7i3SW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d7093-0c76-76d3-93cb-f92249818381-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 54, 'total_tokens': 68, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon does not have a capital. It is Earth’s natural satellite and does not have any permanent human settlements, governments, or cities—meaning there is no capital city or administrative center on the Moon. If you have any other lunar questions, feel free to ask!

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='aa2f7af1-b834-4e75-a889-e6cfcffcc1fa'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='c4f2442f-0bc0-4c5d-81bb-4ce3307f6164', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='185d6ed2-6766-4a0b-9ee5-48a08a9cd65f'),
#               AIMessage(content='As of now, **Luna City** is a fictional or speculative name often used in science fiction to refer to a major settlement or capital on the Moon. There is no real Luna City on the Moon—humanity has not yet established permanent settlements there.\n\n### **In Science Fiction and Popular Culture**\n- **Luna City** appears in various books, movies, and TV shows as the main lunar base or "capital" for lunar inhabitants.\n- It sometimes represents the center of government, commerce, and life for lunar colonists.\n\n#### Examples:\n- **Robert A. Heinlein’s novels** (such as *The Moon is a Harsh Mistress*): Luna City is one of the primary lunar settlements.\n- **Other works**: Many writers, game developers, and filmmakers have used the name for lunar cities or colonies.\n\n### **In Real Life**\n- No official lunar city exists. As of 2024, the Moon is uninhabited except for brief stays by astronauts in lunar modules or landers.\n- Future plans by NASA, ESA, and other space agencies do envision establishing lunar bases or even cities—some proposals and concept art use names like Luna City or Lunar City.\n\n### **Summary**\n- **Luna City** is not real (yet)—it is a creation of fiction and imagination.\n- There is no official capital of the Moon; the Moon remains without inhabitants or governments.\n\nIf you’re interested in visions of future Moon cities or plans for lunar bases, let me know—I can tell you more about current Moon colonization concepts!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 316, 'prompt_tokens': 39, 'total_tokens': 355, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_07725604d8', 'id': 'chatcmpl-DSbd8GoQoQ6DyVLPg4MjcxOpqfSYI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d7093-76fb-7cb1-b980-06997da41fa6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 316, 'total_tokens': 355, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# As{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  of{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  June{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  {'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# 202{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# 4{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  **{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# L{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# una{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  City{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# **{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  is{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  a{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  *{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# fiction{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# al{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  or{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  speculative{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  concept{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# *{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  and{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  not{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  an{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  existing{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  location{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  since{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  humanity{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  has{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  not{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  built{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  permanent{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  cities{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  or{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  capitals{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  on{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  the{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  Moon{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# .{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  However{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  the{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  idea{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  of{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  "{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# L{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# una{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  City{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  capital{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  of{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  the{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  Moon{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# "{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  is{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  a{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  popular{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  theme{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  in{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  science{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  fiction{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  space{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  advocacy{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  circles{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  and{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  future{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# -l{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# unar{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# -set{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# t{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# lements{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  discussions{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# .{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  Here{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ’s{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  an{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  overview{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  based{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  on{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  science{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  fiction{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  and{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  speculative{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  envision{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ing{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# :
#
# {'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ---
#
# {'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ##{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  **{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# In{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  Science{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  Fiction{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# **
# {'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# -{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  **{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# Classic{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  Works{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# :**{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  "{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# L{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# una{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  City{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# "{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  appears{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  as{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  a{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  setting{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  in{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ...
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  and{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  vision{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# aries{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# .{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  If{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  you{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ’re{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  interested{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  in{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  a{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  version{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  of{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  Luna{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  City{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  from{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  a{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  particular{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  novel{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  TV{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  series{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  or{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  game{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# ,{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  let{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  me{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  know{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  and{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  I{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  can{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  provide{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  more{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  specific{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
#  details{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None}
# !{'ls_integration': 'langchain_chat_model', 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'checkpoint_ns': 'model:fdf904ce-c9a5-f00a-835b-0b340ef55e1f', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4.1', 'ls_model_type': 'chat', 'ls_temperature': None, 'usage_metadata': {'input_tokens': 19, 'output_tokens': 766, 'total_tokens': 785, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'LANGSMITH_PROJECT': 'agent', 'revision_id': '8e2b5ef'}
